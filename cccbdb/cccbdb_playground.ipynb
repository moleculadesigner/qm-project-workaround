# %% [markdown]
# # CCCBDB Reqests and parser playground

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
from html.parser import HTMLParser
import pandas as pd
import io
import re
from pathlib import Path

# %%
FORM_URL = "https://cccbdb.nist.gov/getformx.asp"
EXP1_URL = "https://cccbdb.nist.gov/exp1x.asp"
EXP2_URL = "https://cccbdb.nist.gov/exp2x.asp"

def headers(**kwargs):
    defaults = {
        "Host": "cccbdb.nist.gov",
        "Connection": "keep-alive",
        "Content-Length": "26",
        "Pragma": "no-cache",
        "Cache-Control": "no-cache",
        "Origin": "https://cccbdb.nist.gov",
        "Upgrade-Insecure-Requests": "1",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Content-Type": "application/x-www-form-urlencoded",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-CA,en-GB;q=0.8,en-US;q=0.6,en;q=0.4",
        #"Referer": referer, ## Depends on query
    }
    defaults.update(kwargs)
    return defaults

# %%
def get_exp_data_by_cas(cas: int) -> bytes:
    """
    """

    session = requests.Session()
    payload = {
        "formula": cas,
        "submit1": "Submit",
    }
    query_headers = headers(Referer=EXP1_URL)
    print(f"{cas:>12} :: Submitting Query ...")
    query_res = session.post(
        FORM_URL,
        data=payload,
        headers=query_headers,
        allow_redirects=False,
    )
    if query_res.status_code != 302:
        raise requests.RequestException(
            f"Wrong Query responce {query_response.status_code}: must be 302"
        )

    print(f"{cas:>12} :: Collecting Data ...")
    data_res = session.get(EXP2_URL)
    if data_res.status_code != 200:
        raise requests.RequestException(
            f"Wrong Query responce {data_res.status_code}: must be 200"
        )

    return data_res.content

# %%
cas_ids = [
    71432,  # Benzene
    78820,  # 2-methylpropanenitrile
]
for cas in cas_ids:
    print(f"{cas:>12} :: Processing CCCBDB ...")
    for try_ in range(5):
        try:
            data = get_exp_data_by_cas(cas)
            break
        except Exception as e:
            print(f"{cas:>12} :: try {try_ + 1}")
            print(f"{cas:>12} :: {e}")
            sleep(5)
            continue
    with open(f"{cas}.html", "bw") as dump:
        dump.write(data)
    print(f"{cas:>12} :: Done\n")
# Out:
#        71432 :: Processing CCCBDB ...
#        71432 :: Submitting Query ...
#        71432 :: Collecting Data ...
#        71432 :: Done
#
#        78820 :: Processing CCCBDB ...
#        78820 :: Submitting Query ...
#        78820 :: Collecting Data ...
#        78820 :: Done

# %% [markdown]
# ## Parse Tables

# %%
with open("71432.html", "br") as htm:
    content = htm.read()
soup = BeautifulSoup(content, 'html.parser')

# %%
def decorate_html(tag):
    return io.StringIO(
        "<!DOCTYPE HTML><html><body>"
        f"{tag}"
        "</body></html>"
    )

# %%
vibrations_div = soup.find(
    "div",
    attrs={
        "class": "box",
        "title": "Vibrational symmetries, frequencies, and intensities"
    },
)
vibrations_table = decorate_html(vibrations_div.find('table'))

refs_div = soup.find(
    "div",
    attrs={
        "class": "box",
        "title": "References"
    }
)
refs_table = decorate_html(refs_div.find("table", attrs={"id": "reftable"}))

# %%
pd.read_html(vibrations_table)[0]
# Out:
#    Mode Number Symmetry         Frequency                           Intensity  \
#    Mode Number Symmetry Fundamental(cm-1) Harmonic(cm-1) Reference (km mol-1)
# 0            1      A1g              3062            NaN      Shim        NaN
# 1            2      A1g               992            NaN      Shim        NaN
# 2            3      A2g              1326            NaN      Shim        NaN
# 3            4      A2u               673            NaN      Shim        NaN
# 4            5      B1u              3068            NaN      Shim        NaN
# 5            6      B1u              1010            NaN      Shim        NaN
# 6            7      B2g               995            NaN      Shim        NaN
# 7            8      B2g               703            NaN      Shim        NaN
# 8            9      B2u              1310            NaN      Shim        NaN
# 9           10      B2u              1150            NaN      Shim        NaN
# 10          11      E1g               849            NaN      Shim        NaN
# 11          12      E1u              3063            NaN      Shim        NaN
# 12          13      E1u              1486            NaN      Shim        NaN
# 13          14      E1u              1038            NaN      Shim        NaN
# 14          15      E2g              3047            NaN      Shim        NaN
# 15          16      E2g              1596            NaN      Shim        NaN
# 16          17      E2g              1178            NaN      Shim        NaN
# 17          18      E2g               606            NaN      Shim        NaN
# 18          19      E2u               975            NaN      Shim        NaN
# 19          20      E2u               410            NaN      Shim        NaN
#
#                   Comment Description
#    unc. Reference Comment Description
# 0   NaN       NaN     NaN         NaN
# 1   NaN       NaN     NaN         NaN
# 2   NaN       NaN     NaN         NaN
# 3   NaN       NaN     NaN         NaN
# 4   NaN       NaN     NaN         NaN
# 5   NaN       NaN     NaN         NaN
# 6   NaN       NaN     NaN         NaN
# 7   NaN       NaN     NaN         NaN
# 8   NaN       NaN     NaN         NaN
# 9   NaN       NaN     NaN         NaN
# 10  NaN       NaN     NaN         NaN
# 11  NaN       NaN     NaN         NaN
# 12  NaN       NaN     NaN         NaN
# 13  NaN       NaN     NaN         NaN
# 14  NaN       NaN     NaN         NaN
# 15  NaN       NaN     NaN         NaN
# 16  NaN       NaN     NaN         NaN
# 17  NaN       NaN     NaN         NaN
# 18  NaN       NaN     NaN         NaN
# 19  NaN       NaN     NaN         NaN

# %%
pd.read_html(refs_table)[0]
# Out:
#              squib                                          reference  \
# 0     1966Herzberg  Herzberg, G., Electronic spectra and electroni...
# 1  1981Bat/Buc:421  MR Battaglia, AD Buckingham, JH Williams "The ...
# 2  1998Gus/Rui:163  M Gussoni, R Rui, G Zerbi "Electronic and rela...
# 3      NSRDS-NBS10  R. D. Nelson Jr., D. R. Lide, A. A. Maryott "S...
# 4             Shim  Shimanouchi, T. , Tables of Molecular Vibratio...
# 5              TRC  Frenkel, M; Marsh, K.N.; Wilhoit, R.C.; Kabo, ...
# 6          webbook  NIST Chemistry Webbook (http://webbook.nist.go...
#
#                              DOI
# 0                            NaN
# 1   10.1016/0009-2614(81)85228-1
# 2  10.1016/S0022-2860(97)00292-5
# 3           10.6028/NBS.NSRDS.10
# 4           10.6028/NBS.NSRDS.39
# 5                            NaN
# 6                10.18434/T4D303

# %% [markdown]
# ### Making function

# %%
def extract_info(cas, html_content, data_dir=Path("./")):
    soup = BeautifulSoup(html_content, 'html.parser')

    vibrations_div = soup.find(
        "div",
        attrs={
            "class": "box",
            "title": "Vibrational symmetries, frequencies, and intensities"
        },
    )
    vibrations_table = decorate_html(vibrations_div.find('table'))
    vibs = pd.read_html(vibrations_table)[0]
    vibs.to_csv(
        data_dir/f"{cas}_vibs.csv",
    )

    refs_div = soup.find(
        "div",
        attrs={
            "class": "box",
            "title": "References"
        }
    )
    refs_table = decorate_html(refs_div.find("table", attrs={"id": "reftable"}))   
    refs = pd.read_html(refs_table)[0]
    refs.to_csv(
        data_dir/f"{cas}_refs.csv",
    )

# %%
for cas in [78820, 71432]:
    with open(f"{cas}.html", "br") as html_handler:
        html_content = html_handler.read()
    extract_info(cas, html_content)

# %% [markdown]
# ## Full List of Compounds

# %%
raw_table = pd.read_html("cccbdb_list.html", extract_links="body")[3]

# %%
raw_table
# Out:
#                                                link           species  \
#                                              1 atom            1 atom
# 0     (data, alldata2.asp?casno=12385136&charge=-1)        (H-, None)
# 1      (data, alldata2.asp?casno=12385136&charge=0)         (H, None)
# 2      (data, alldata2.asp?casno=12385136&charge=1)        (H+, None)
# 3     (data, alldata2.asp?casno=16873179&charge=-1)        (D-, None)
# 4      (data, alldata2.asp?casno=16873179&charge=0)         (D, None)
# ...                                             ...               ...
# 2213     (data, alldata2.asp?casno=519733&charge=0)    (C19H16, None)
# 2214                               (36 atoms, None)  (36 atoms, None)
# 2215     (data, alldata2.asp?casno=191071&charge=0)    (C24H12, None)
# 2216                               (60 atoms, None)  (60 atoms, None)
# 2217   (data, alldata2.asp?casno=99685968&charge=0)       (C60, None)
#
#                               name             atoms            sketch
#                             1 atom            1 atom            1 atom
# 0      (Hydrogen atom anion, None)         (1, None)        (H-, None)
# 1            (Hydrogen atom, None)         (1, None)         (H, None)
# 2     (Hydrogen atom cation, None)         (1, None)        (H+, None)
# 3     (Deuterium atom anion, None)         (1, None)        (D-, None)
# 4           (Deuterium atom, None)         (1, None)         (D, None)
# ...                            ...               ...               ...
# 2213      (Triphenylmethane, None)        (35, None)          (, None)
# 2214              (36 atoms, None)  (36 atoms, None)  (36 atoms, None)
# 2215              (Coronene, None)        (36, None)          (, None)
# 2216              (60 atoms, None)  (60 atoms, None)  (60 atoms, None)
# 2217  (Buckminsterfullerene, None)        (60, None)          (, None)
#
# [2218 rows x 5 columns]

# %%
processed_table = pd.DataFrame()

# %%
cas_ch_re = re.compile(r"^alldata2.asp\?casno=(\d+)\&charge=([-+]?[0-9]+)$", re.X|re.I)
def extract_cas(line):
    if not isinstance(line, str):
        return None
    m = cas_ch_re.match(line)
    if m:
        return m.group(1)

def extract_ch(line):
    if not isinstance(line, str):
        return None
    m = cas_ch_re.match(line)
    if m:
        return int(m.group(2))

# %%
extract_cas("alldata2.asp?casno=7440553&charge=-1")
# Out:
# '7440553'

# %%
extract_ch("alldata2.asp?casno=7440553&charge=-1")
# Out:
# -1

# %%
processed_table["link"] = raw_table[("link", '1 atom')].map(
    lambda val: val[1]
)
processed_table["species"] = raw_table[("species", '1 atom')].map(
    lambda val: val[0]
)
processed_table["name"] = raw_table[("name", '1 atom')].map(
    lambda val: val[0]
)
processed_table["atoms"] = raw_table[("atoms", '1 atom')].map(
    lambda val: int(val[0]) if val[0].isdigit() else 0
)
processed_table["cas_no"] = processed_table["link"].map(
    extract_cas
)
processed_table["charge"] = processed_table["link"].map(
    extract_ch
)

# %%
processed_table.sort_values(["atoms", "cas_no"], axis=0).head(40)
# Out:
#                                        link   species                   name  \
# 107                                    None   2 atoms                2 atoms
# 558                                    None   3 atoms                3 atoms
# 826                                    None   4 atoms                4 atoms
# 1050                                   None   5 atoms                5 atoms
# 1227                                   None   6 atoms                6 atoms
# 1371                                   None   7 atoms                7 atoms
# 1454                                   None   8 atoms                8 atoms
# 1579                                   None   9 atoms                9 atoms
# 1646                                   None  10 atoms               10 atoms
# 1723                                   None  11 atoms               11 atoms
# 1790                                   None  12 atoms               12 atoms
# 1885                                   None  13 atoms               13 atoms
# 1950                                   None  14 atoms               14 atoms
# 2008                                   None  15 atoms               15 atoms
# 2045                                   None  16 atoms               16 atoms
# 2093                                   None  17 atoms               17 atoms
# 2110                                   None  18 atoms               18 atoms
# 2155                                   None  19 atoms               19 atoms
# 2159                                   None  20 atoms               20 atoms
# 2173                                   None  21 atoms               21 atoms
# 2178                                   None  22 atoms               22 atoms
# 2183                                   None  23 atoms               23 atoms
# 2188                                   None  24 atoms               24 atoms
# 2197                                   None  26 atoms               26 atoms
# 2202                                   None  27 atoms               27 atoms
# 2204                                   None  28 atoms               28 atoms
# 2206                                   None  29 atoms               29 atoms
# 2208                                   None  30 atoms               30 atoms
# 2210                                   None  32 atoms               32 atoms
# 2212                                   None  35 atoms               35 atoms
# 2214                                   None  36 atoms               36 atoms
# 2216                                   None  60 atoms               60 atoms
# 93    alldata2.asp?casno=10097322&charge=-1       Br-     Bromine atom anion
# 94     alldata2.asp?casno=10097322&charge=0        Br           Bromine atom
# 95     alldata2.asp?casno=10097322&charge=1       Br+    Bromine atom cation
# 0     alldata2.asp?casno=12385136&charge=-1        H-    Hydrogen atom anion
# 1      alldata2.asp?casno=12385136&charge=0         H          Hydrogen atom
# 2      alldata2.asp?casno=12385136&charge=1        H+   Hydrogen atom cation
# 101    alldata2.asp?casno=13494809&charge=0        Te         Tellurium atom
# 102    alldata2.asp?casno=13494809&charge=1       Te+  Tellurium atom cation
#
#       atoms    cas_no  charge
# 107       0      None     NaN
# 558       0      None     NaN
# 826       0      None     NaN
# 1050      0      None     NaN
# 1227      0      None     NaN
# 1371      0      None     NaN
# 1454      0      None     NaN
# 1579      0      None     NaN
# 1646      0      None     NaN
# 1723      0      None     NaN
# 1790      0      None     NaN
# 1885      0      None     NaN
# 1950      0      None     NaN
# 2008      0      None     NaN
# 2045      0      None     NaN
# 2093      0      None     NaN
# 2110      0      None     NaN
# 2155      0      None     NaN
# 2159      0      None     NaN
# 2173      0      None     NaN
# 2178      0      None     NaN
# 2183      0      None     NaN
# 2188      0      None     NaN
# 2197      0      None     NaN
# 2202      0      None     NaN
# 2204      0      None     NaN
# 2206      0      None     NaN
# 2208      0      None     NaN
# 2210      0      None     NaN
# 2212      0      None     NaN
# 2214      0      None     NaN
# 2216      0      None     NaN
# 93        1  10097322    -1.0
# 94        1  10097322     0.0
# 95        1  10097322     1.0
# 0         1  12385136    -1.0
# 1         1  12385136     0.0
# 2         1  12385136     1.0
# 101       1  13494809     0.0
# 102       1  13494809     1.0

# %%
data_to_store = processed_table[processed_table["charge"] == 0].drop("link", axis=1)
data_to_store
# Out:
#      species                  name  atoms    cas_no  charge
# 1          H         Hydrogen atom      1  12385136     0.0
# 4          D        Deuterium atom      1  16873179     0.0
# 7         He           Helium atom      1   7440597     0.0
# 10        Li          Lithium atom      1   7439932     0.0
# 13        Be        Beryllium atom      1   7440417     0.0
# ...      ...                   ...    ...       ...     ...
# 2209  C18H12             Tetracene     30     92240     0.0
# 2211  C10H22                Decane     32    124185     0.0
# 2213  C19H16      Triphenylmethane     35    519733     0.0
# 2215  C24H12              Coronene     36    191071     0.0
# 2217     C60  Buckminsterfullerene     60  99685968     0.0
#
# [1586 rows x 5 columns]

# %%
data_to_store.to_csv("all_neutrals_cccbdb.csv", index=False)
